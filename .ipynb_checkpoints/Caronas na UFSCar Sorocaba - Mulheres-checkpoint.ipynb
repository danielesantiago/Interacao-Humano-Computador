# %% [markdown]
# # Caronas na UFSCar Sorocaba - Mulheres
#
# <b>Os Objetivos de Desenvolvimento Sustentável no Brasil</b> são um apelo global à ação para acabar com a pobreza, proteger o meio ambiente e o clima e garantir que as pessoas, em todos os lugares, possam desfrutar de paz e de prosperidade. Baseado no objetivo 5, <b>alcançar a igualdade de gênero e empoderar todas as mulheres e meninas</b>, o grupo propôs a criação de um sistema de caronas focado exclusivamente em mulheres. A ideia central é que mulheres do <b>campus UFSCar Sorocaba</b> possam oferecer caronas que contenham a UFSCar como ponto no trajeto.

# %% [markdown]
# <img src="Arquivos/woman.jpg"  width=80%>

# %% [markdown]
# A ideia abrange os pontos posteriormente citados, haja vista que um sistema de caronas focado exclusivamente em mulheres ajuda a eliminar formas de violência e abuso e a tecnlogia é utiliza para favorecer o empoderamento feminino.
#
# * (5.a) Realizar reformas para dar às mulheres direitos iguais aos recursos econômicos, bem como o acesso a propriedade e controle sobre a terra e outras formas de propriedade, serviços financeiros, herança e os recursos naturais, de acordo com as leis nacionais
#
# * (5.b) Aumentar o uso de tecnologias de base, em particular as tecnologias de informação e comunicação, para promover o empoderamento das mulheres

# %% [markdown]
# <h2>Obtenção dos Dados</h2>
#
# Os dados foram obtidos a partir de uma pesquisa de mercado realizada com os alunos e docentes do campus.

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import numpy as np
import folium

# %matplotlib inline
# tamanho dos gráficos
plt.rcParams["figure.figsize"] = [10,5]
# tamanho dos dados
plt.rcParams["font.size"] = 12

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv("arquivos/pesquisa_mercado.csv", sep = ',')

# %% [markdown]
# <h2>Análise dos Dados</h2>
#
# Esta etapa tem por objetivo criar uma consciência situacional inicial e permitir um entendimento de como os dados estão estruturados. Houveram perguntas gerais, e depois fora dado um direcionamento especifico a depender do meio de transporte utilizado pelos indivíduos.
#
# **Perguntas realizadas**
#
# * `1. Com qual gênero você se identifica?`
# * `2. Qual o município de Sorocaba ou região que você reside atualmente?`
# * `3. Com qual frequência você está na UFSCar Sorocaba?`
# * `4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?`
# - Ônibus
# - Carro Próprio
# - Carona
# - Uber/Táxi
# * `5. O quão você se sente segura:`
# - Em caronas?
# - Em transporte público?
# - Em Táxi/Uber?
# - Com um motorista do gênero oposto?
# - Com um motorista do mesmo gênero?
#
# <b>Para usuários que utilizam como meio de transporte ônibus, carona ou uber/taxi, as perguntas foram:</b>
#
# * `6. Em quais condições você estaria disposta a pegar caronas com mulheres da UFSCar? Se em nenhuma condição, por quê?`
# * `7. Com que frequência você requisitaria carona?`
# - 1-2 vezes por semana
# - 3-5 vezes por semana
# - Mensalmente
# - Só em casos de emergência
# - Não requisitaria
# * `8. Ao requisitar uma carona o quão importante é`
# - Escolher o motorista?
# -  Saber previamente dados do motorista?
# - A carona ser gratuita?
# - Conversar previamente com o motorista?
# - Ter o gênero do motorista verificado?
#
# <b>Para usuários que utilizam como meio de transporte carro próprio, as perguntas foram:</b>
#
# * `6. Em que condições você estaria disposta a oferecer caronas às mulheres que frequentam a UFSCar? Se em nenhuma condição, por quê?`
# * `7. Com que frequência você ofereceria carona?`
# - 1-2 vezes por semana
# - 3-5 vezes por semana
# - Mensalmente
# - Ocasionalmente
# - Não ofereceria
# * `8. Ao oferecer uma carona o quão importante é:`
# - Saber previamente o trajeto?
# - Saber previamente dados do usuário?
# - Dividir as despesas?
# - Conversar previamente com o usuário?
# - Ter o gênero do usuário verificado?

# %% [markdown]
# ## Parte I - Perguntas Gerais
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui?**
#
# Vamos prosseguir e identificar a quantidade de entradas que nosso conjunto de dados possui e observar as categorias de cada coluna.

# %%
print("Entradas: ", df[df.columns[0]].count())
print("Variáveis: ", df.shape[1])
# Out:
# Entradas:  38
# Variáveis:  24

# %%
# verificar as 5 primeiras entradas do dataset
df.head()
# Out:
#            Carimbo de data/hora 1. Com qual gênero você se identifica?  \
# 0  2022/07/10 12:03:29 PM GMT-3                              Masculino
# 1  2022/07/10 12:04:15 PM GMT-3                               Feminino
# 2  2022/07/10 12:05:00 PM GMT-3                              Masculino
# 3  2022/07/10 12:05:10 PM GMT-3                               Feminino
# 4  2022/07/10 12:07:00 PM GMT-3                              Masculino
#
#   2. Qual o município de Sorocaba ou região que você reside atualmente?  \
# 0                                           Sorocaba
# 1                                         Votorantim
# 2                                           Sorocaba
# 3                                           Sorocaba
# 4                                           Sorocaba
#
#   3. Com qual frequência você está na UFSCar Sorocaba?  \
# 0                             1 - 2 vezes por semana
# 1                             3 - 5 vezes por semana
# 2                             3 - 5 vezes por semana
# 3                             3 - 5 vezes por semana
# 4                             3 - 5 vezes por semana
#
#   4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?  \
# 0                                             Carona
# 1                                             Carona
# 2                                             Ônibus
# 3                                             Ônibus
# 4                                             Ônibus
#
#   5. O quão você se sente segura: [Em caronas?]  \
# 0                                  Muito segura
# 1                          Razoavelmente segura
# 2                          Razoavelmente segura
# 3                                  Pouco segura
# 4                          Razoavelmente segura
#
#   5. O quão você se sente segura: [Em transporte público?]  \
# 0                               Razoavelmente segura
# 1                               Razoavelmente segura
# 2                                       Muito segura
# 3                                       Muito segura
# 4                                       Muito segura
#
#   5. O quão você se sente segura: [Em Táxi/Uber?]  \
# 0                                    Muito segura
# 1                            Razoavelmente segura
# 2                            Razoavelmente segura
# 3                            Razoavelmente segura
# 4                            Razoavelmente segura
#
#   5. O quão você se sente segura: [Com um motorista do gênero oposto?]  \
# 0                                       Muito segura
# 1                               Razoavelmente segura
# 2                                       Muito segura
# 3                                        Nada segura
# 4                               Razoavelmente segura
#
#   5. O quão você se sente segura: [Com um motorista do mesmo gênero?]  ...  \
# 0                                       Muito segura                   ...
# 1                                       Muito segura                   ...
# 2                               Razoavelmente segura                   ...
# 3                               Razoavelmente segura                   ...
# 4                               Razoavelmente segura                   ...
#
#   8. Ao requisitar uma carona o quão importante é [A carona ser gratuita?]  \
# 0                                   Pouco importante
# 1                           Razoavelmente importante
# 2                           Razoavelmente importante
# 3                                   Pouco importante
# 4                                    Nada importante
#
#   8. Ao requisitar uma carona o quão importante é [Conversar previamente com o motorista?]  \
# 0                           Razoavelmente importante
# 1                                   Muito importante
# 2                                    Nada importante
# 3                                   Muito importante
# 4                           Razoavelmente importante
#
#   8. Ao requisitar uma carona o quão importante é [Ter o gênero do motorista verificado?]  \
# 0                           Razoavelmente importante
# 1                                   Muito importante
# 2                                   Muito importante
# 3                                   Muito importante
# 4                                   Pouco importante
#
#   6. Em que condições você estaria disposta a oferecer caronas às mulheres que frequentam a UFSCar? Se em nenhuma condição, por quê?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   7. Com que frequência você ofereceria carona?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   8. Ao oferecer uma carona o quão importante é: [Saber previamente o trajeto?]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8. Ao oferecer uma carona o quão importante é: [Saber previamente dados do usuário?]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8. Ao oferecer uma carona o quão importante é: [Dividir as despesas?]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8. Ao oferecer uma carona o quão importante é: [Conversar previamente com o usuário?]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8. Ao oferecer uma carona o quão importante é: [Ter o gênero do usuário verificado?]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# De início, podemos observar que alguns indíviduos do gênero masculino responderam a pesquisa, logo precisamos realizar uma limpeza nos dados para analisar somente o público alvo. A seguir, veremos a quantidade de pessoas de cada gênero que responderam a pesquisa.

# %%
# verifica porcentagem de cada gênero
round(df['1. Com qual gênero você se identifica?'].value_counts()/df.shape[0],2) * 100
# Out:
# Feminino     55.0
# Masculino    45.0
# Name: 1. Com qual gênero você se identifica?, dtype: float64

# %% [markdown]
# Agora limparemos os dados para manter apenas pessoas que se identificam com o gênero feminino.

# %%
# realiza limpeza de dados
df_fem = df.loc[df['1. Com qual gênero você se identifica?'] == 'Feminino']

# %% [markdown]
# Por fim, observaremos novamente a porcentagem de cada gênero.

# %%
# verifica porcentagem de cada gênero
round(df_fem['1. Com qual gênero você se identifica?'].value_counts()/df_fem.shape[0],2) * 100
# Out:
# Feminino    100.0
# Name: 1. Com qual gênero você se identifica?, dtype: float64

# %%
# ver quantidade de respostas totais pós limpeza
df_fem.shape[0]
# Out:
# 21

# %% [markdown]
# ### Q2. Em qual municipio há mais mulheres?

# %% [markdown]
# Podemos observar que:
# <ul>
#     <li> De modo geral, mais de 70% das mulheres que responderam o questionário vivem em Sorocaba.</li>
#     <li> 60% das mulheres que possuem veículo próprio vivem em Votorantim.</li>
#     <li> Mais de 80% das mulheres que não possuem veículo próprio vivem em Sorocaba.</li>
# </ul>

# %%
# Plotando gráficos para questão 2
fig, ax = plt.subplots()

# definir informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_fem.groupby("2. Qual o município de Sorocaba ou região que você reside atualmente?").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax.grid(False)

# gráfico da quantidade de pessoas por município
ax2 = sns.barplot(x= df_fem['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().index, palette=np.array(pal[::-1])[rank], ax = ax)
ax2.set_xlabel('Porcentagem de Pessoas')
ax2.set_ylabel('Municípios')
ax2.set_title("Gráfico (Municípios x Porcentagem de Pessoas)");

# %%
# Plotando gráficos para questão 2
fig, ax = plt.subplots()

df_copia = df_fem.copy()

# mulheres que possuem veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] == 'Carro Próprio']

# definir informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_copia.groupby("2. Qual o município de Sorocaba ou região que você reside atualmente?").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax.grid(False)

# gráfico da quantidade de pessoas por município
ax2 = sns.barplot(x= df_copia['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().values/df_copia.shape[0] * 100, y= df_copia['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().index, palette=np.array(pal[::-1])[rank], ax = ax)
ax2.set_xlabel('Porcentagem de Pessoas')
ax2.set_ylabel('Municípios')
ax2.set_title("Gráfico (Municípios x Porcentagem de Pessoas) - Mulheres com veículo próprio");

# %%
# Plotando gráficos para questão 2
fig, ax = plt.subplots()

df_copia = df_fem.copy()

# mulheres que não possum veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] != 'Carro Próprio']

# definir informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_copia.groupby("2. Qual o município de Sorocaba ou região que você reside atualmente?").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax.grid(False)

# gráfico da quantidade de pessoas por município
ax2 = sns.barplot(x= df_copia['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().values/df_copia.shape[0] * 100, y= df_copia['2. Qual o município de Sorocaba ou região que você reside atualmente?'].value_counts().index, palette=np.array(pal[::-1])[rank], ax = ax)
ax2.set_xlabel('Porcentagem de Pessoas')
ax2.set_ylabel('Municípios')
ax2.set_title("Gráfico (Municípios x Porcentagem de Pessoas) - Mulheres sem veículo próprio");

# %% [markdown]
# ### Q3. Com qual frequência, as mulheres estão na UFSCar Sorocaba?

# %% [markdown]
# Podemos perceber que de modo geral, mais de 95% das mulheres estão presentes na UFSCar de 3 a 5 vezes por semana.

# %%
df_fem['3. Com qual frequência você está na UFSCar Sorocaba?'].value_counts()/df_fem.shape[0] * 100
# Out:
# 3 - 5 vezes por semana    95.238095
# 1 - 2 vezes por semana     4.761905
# Name: 3. Com qual frequência você está na UFSCar Sorocaba?, dtype: float64

# %% [markdown]
# Quando restrigimos os dados para as mulheres que possuem carro próprio, 80% está presente de 3 a 5 vezes por semana

# %%
df_copia = df_fem.copy()
# mulheres que possuem veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] == 'Carro Próprio']
df_copia['3. Com qual frequência você está na UFSCar Sorocaba?'].value_counts()/df_copia.shape[0] * 100
# Out:
# 3 - 5 vezes por semana    80.0
# 1 - 2 vezes por semana    20.0
# Name: 3. Com qual frequência você está na UFSCar Sorocaba?, dtype: float64

# %% [markdown]
# Já para as mulheres que não possuem veículo próprio, 100% está presente no campus de 3 a 5 vezes durante a semana

# %%
df_copia = df_fem.copy()
# mulheres que não possuem veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] != 'Carro Próprio']
df_copia['3. Com qual frequência você está na UFSCar Sorocaba?'].value_counts()/df_copia.shape[0] * 100
# Out:
# 3 - 5 vezes por semana    100.0
# Name: 3. Com qual frequência você está na UFSCar Sorocaba?, dtype: float64

# %% [markdown]
# ### Q4. Qual o meio de transporte mais utilizado para ir à UFSCar?

# %% [markdown]
# Pode-se notar que mais de 60% das mulheres utilizam ônibus como meio de transporte, enquanto mais de 20% possuem carro próprio.

# %%
df_fem['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'].value_counts()/df_fem.shape[0] * 100
# Out:
# Ônibus           66.666667
# Carro Próprio    23.809524
# Uber/Táxi         4.761905
# Carona            4.761905
# Name: 4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?, dtype: float64

# %%
# Plotando gráficos para questão 2
fig, ax = plt.subplots()

# definir informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_fem.groupby("4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax.grid(False)

# gráfico da quantidade de pessoas por município
ax2 = sns.barplot(x= df_fem['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'].value_counts().index, palette=np.array(pal[::-1])[rank], ax = ax)
ax2.set_xlabel('Porcentagem de Pessoas')
ax2.set_ylabel('Meio de transporte')
ax2.set_title("Gráfico (Meio de transporte x Porcentagem de Pessoas)");

# %% [markdown]
# ### Q5. Quão seguras as mulheres se sentem em diversas situações?

# %% [markdown]
# Pode-se notar que:
# * Aproximadamente 40% das mulheres se sentem razoavelmente seguras em caronas, enquanto mais de 25% se sentem pouco seguras.
# * Mais de 60% das mulheres se sentem razoavelmente seguras em transporte público.
# * Mais de 60% das mulheres se sentem razoavelmente seguras em táxi/uber, enquanto 30% se sentem pouco seguras.
# * 50% das mulheres se sentem pouco seguras com motoristas homens e 20% se sentem nada seguras.
# * Mais de 60% das mulheres se sentem razoavelmente seguras com motoristas mulheres, enquanto o complemento se sente muito segura.

# %%
# plotar gráficos para as informações obtidas
 
fig, ax= plt.subplots(3, 2,figsize=(12, 15))
fig.delaxes(ax[2,1])
fig = plt.subplots_adjust(wspace= 0.5)

# define informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_fem.groupby("5. O quão você se sente segura: [Em caronas?]").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax[0,0].grid(False)
ax[0,1].grid(False)
ax[1,0].grid(False)
ax[1,1].grid(False)
ax[2,0].grid(False)

# Caronas
ax2 = sns.barplot(x= df_fem['5. O quão você se sente segura: [Em caronas?]'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['5. O quão você se sente segura: [Em caronas?]'].value_counts().index, palette=np.array(pal[::-1])[rank], order = df_fem['5. O quão você se sente segura: [Em caronas?]'].value_counts().sort_values(ascending = False).index , ax = ax[0,0])
ax2.set_title("Em caronas?");

# Transporte Público
ax2 = sns.barplot(x= df_fem['5. O quão você se sente segura: [Em transporte público?]'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['5. O quão você se sente segura: [Em transporte público?]'].value_counts().sort_values(ascending = False).index , ax = ax[0,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Em transporte público?");

# Taxi/Uber
ax2 = sns.barplot(x= df_fem['5. O quão você se sente segura: [Em Táxi/Uber?]'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['5. O quão você se sente segura: [Em Táxi/Uber?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("Em táxi/uber?");
    
# Motorista do gênero oposto
ax2 = sns.barplot(x= df_fem['5. O quão você se sente segura: [Com um motorista do gênero oposto?]'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['5. O quão você se sente segura: [Com um motorista do gênero oposto?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Com um motorista do gênero oposto?");

# Motorista do mesmo gênero
ax2 = sns.barplot(x= df_fem['5. O quão você se sente segura: [Com um motorista do mesmo gênero?]'].value_counts().values/df_fem.shape[0] * 100, y= df_fem['5. O quão você se sente segura: [Com um motorista do mesmo gênero?]'].value_counts().sort_values(ascending = False).index , ax = ax[2,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("Com um motorista do mesmo gênero?");

# %% [markdown]
# ## Parte II - Mulheres sem veículo de transporte próprio
# ### Q6. Em quais condições as mulheres estariam dispostas a pegar caronas com mulheres da UFSCar?

# %% [markdown]
# Primeiramente, iremos observar quantas mulheres não possuem veículo próprio e sua porcentagem perante o conjunto de dados.

# %%
df_copia = df_fem.copy()
# quantidade mulheres que não possuem veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] != 'Carro Próprio']
df_copia.shape[0]
# Out:
# 16

# %%
# porcentagem de mulheres que não possuem veículo próprio
round(df_copia.shape[0]/df_fem.shape[0] * 100,2)
# Out:
# 76.19

# %% [markdown]
# Agora observaremos as condições para pegar caronas.

# %%
num = 1
for motivo in df_copia['6. Em quais condições você estaria disposta a pegar caronas com mulheres da UFSCar? Se em nenhuma condição, por quê?']:
    print(num, '', motivo, '\n')
    num = num + 1
# Out:
# 1  Acho que qualquer condição, mas se eu conhecesse seria melhor
#
# 2  Ônibus lotado ou após as 22h para não chegar tarde em casa
#
# 3  Estou disposta
#
# 4  Em qualquer condição desde que houvesse uma forma para que eu conhecesse a pessoa antes da carona.
#
# 5  Eu estaria disposta a pegar caronas com mulheres da UFSCar em momentos de urgência ou para ir em lugares que o ônibus não me levaria, principalmente em rolês com amigos.
#
# 6  Com o trajeto passando onde moro, e com um valor acessível.
#
# 7  Qualquer condição
#
# 8  Pegar carona somente com mulheres da ufscar e se tivesse uma forma de sabermos quem está disposta a dar carona, através de um app ou um cartaz informativo, redes sociais, etc, ficaria mais fácil e mais seguro.
#
# 9  sim, pegaria carona com mulheres para ir embora para não chegar tao tarde em casa
#
# 10  Prefiro
#
# 11  estaria 100% disposta
#
# 12  Conhecidas somente.
#
# 13  Todas
#
# 14  Se eu conhecer a pessoa ou alguém que eu confio conhecer
#
# 15  Em tds as condições.
#
# 16  Apenas se eu conhecer a pessoa.

# %% [markdown]
# ### Q7. Com qual frequência as mulheres requisitariam carona?

# %% [markdown]
# Podemos notar que a maioria requisitaria 1 a 2 vezes por semana ou só em casos de emergência.

# %%
df_copia['7. Com que frequência você requisitaria carona?'].value_counts()/df_copia.shape[0] * 100
# Out:
# 1-2 vezes por semana         43.75
# Só em casos de emergência    37.50
# 3-5 vezes por semana         18.75
# Name: 7. Com que frequência você requisitaria carona?, dtype: float64

# %% [markdown]
# ### Q8. O que é importante para as mulheres ao requisitar uma carona?

# %% [markdown]
# Pode-se notar que:
# * 40% das mulheres acham muito importante poder escolher a motorista.
# * 60% das mulheres acham muito importante saber previamente dados da motorista.
# * Mais de 40% das mulheres acham pouco importante a carona ser gratuita.
# * 50% das mulheres acham razoavelmente importante conversar previamente com a motorista.
# * Mais de 50% das mulheres acham muito importante ter o gênero do motorista verificado.

# %%
# plotar gráficos para as informações obtidas
 
fig, ax= plt.subplots(3, 2,figsize=(12, 15))
fig.delaxes(ax[2,1])
fig = plt.subplots_adjust(wspace= 0.5)

# define informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_fem.groupby("8. Ao requisitar uma carona o quão importante é [Escolher o motorista?]").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax[0,0].grid(False)
ax[0,1].grid(False)
ax[1,0].grid(False)
ax[1,1].grid(False)
ax[2,0].grid(False)


# Caronas
ax2 = sns.barplot(x= df_copia["8. Ao requisitar uma carona o quão importante é [Escolher o motorista?]"].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia["8. Ao requisitar uma carona o quão importante é [Escolher o motorista?]"].value_counts().index, 
                  palette=np.array(pal[::-1])[rank], ax = ax[0,0])
ax2.set_title("Escolher o motorista?");

# Transporte Público
ax2 = sns.barplot(x= df_copia["8. Ao requisitar uma carona o quão importante é [Saber previamente dados do motorista?]"].value_counts().values/df_copia.shape[0] * 100,
                  y= df_copia["8. Ao requisitar uma carona o quão importante é [Saber previamente dados do motorista?]"].value_counts().sort_values(ascending = False).index , 
                  ax = ax[0,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Saber previamente dados do motorista?");

# Taxi/Uber
ax2 = sns.barplot(x= df_copia['8. Ao requisitar uma carona o quão importante é [A carona ser gratuita?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao requisitar uma carona o quão importante é [A carona ser gratuita?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("A carona ser gratuita?");
    
# Motorista do gênero oposto
ax2 = sns.barplot(x= df_copia['8. Ao requisitar uma carona o quão importante é [Conversar previamente com o motorista?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao requisitar uma carona o quão importante é [Conversar previamente com o motorista?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Conversar previamente com o motorista?");

# Motorista do mesmo gênero
ax2 = sns.barplot(x= df_copia['8. Ao requisitar uma carona o quão importante é [Ter o gênero do motorista verificado?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao requisitar uma carona o quão importante é [Ter o gênero do motorista verificado?]'].value_counts().sort_values(ascending = False).index , ax = ax[2,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("Ter o gênero do motorista verificado?");

# %% [markdown]
# ## Parte III - Mulheres com veículo de transporte próprio
# ### Q9. Em quais condições as mulheres estariam dispostas a oferecer caronas para as mulheres da UFSCar?

# %% [markdown]
# Primeiramente, iremos observar quantas mulheres possuem veículo próprio e sua porcentagem perante o conjunto de dados.

# %%
df_copia = df_fem.copy()
# quantidade mulheres que não possuem veículo próprio
df_copia = df_copia.loc[df_copia['4. Qual meio de transporte você utiliza majoritariamente para ir à UFSCar Sorocaba?'] == 'Carro Próprio']
df_copia.shape[0]
# Out:
# 5

# %%
# porcentagem de mulheres que não possuem veículo próprio
round(df_copia.shape[0]/df_fem.shape[0] * 100,2)
# Out:
# 23.81

# %% [markdown]
# Agora observaremos as condições para oferecer caronas.

# %%
num = 1
for motivo in df_copia['6. Em que condições você estaria disposta a oferecer caronas às mulheres que frequentam a UFSCar? Se em nenhuma condição, por quê?']:
    print(num, '', motivo, '\n')
    num = num + 1
# Out:
# 1  Mulheres que conheço ou que tenho algum tipo de contato, que possam ajudar na gasolina.
#
# 2  Se moram perto de mim, sim
#
# 3  Condição de eu ja ser conhecida dessa mulher
#
# 4  Conhecendo a pessoa, ou se o contexto em que a pessoa estiver der indícios de ter vínculo com a UFSCar (aluna, TA ou docente)
#
# 5  É só a pessoa usar máscara durante o trajeto. Daria carona sempre que possivel.

# %% [markdown]
# ### Q10. Com qual frequência as mulheres ofereceriam carona?

# %% [markdown]
# Podemos notar que 60% das mulheres ofereceriam carona de 3 a 5 vezes por semana, enquanto o restante ofereceria 1 a 2 vezes ou ocasionalmente.

# %%
df_copia['7. Com que frequência você ofereceria carona?'].value_counts()/df_copia.shape[0] * 100
# Out:
# 3-5 vezes por semana    60.0
# 1-2 vezes por semana    20.0
# Ocasionalmente          20.0
# Name: 7. Com que frequência você ofereceria carona?, dtype: float64

# %% [markdown]
# ### Q11. O que é importante para as mulheres ao oferecer carona?

# %% [markdown]
# Observa-se que:
# * 80% das mulheres acham muito importante saber previamente o trajeto.
# * 60% das mulheres acham muito importante saber previamente os dados do usuário.
# * 60% das mulheres acham muito importante dividir a despesas, e 40% acham pouco importante.
# * 60% das mulheres acham muito importante conversar previamente com o usuário.
# * 60% das mulheres acham muito importante ter o gênero do usuário verificado, e 40% acham pouco importante.

# %%
# plotar gráficos para as informações obtidas
 
fig, ax= plt.subplots(3, 2,figsize=(12, 15))
fig.delaxes(ax[2,1])
fig = plt.subplots_adjust(wspace= 0.5)

# define informações iniciais referentes à coloração
sns.set(style="whitegrid", color_codes=True)
data = df_fem.groupby("8. Ao oferecer uma carona o quão importante é: [Saber previamente o trajeto?]").size() 
pal = sns.color_palette("rocket", len(data))
rank = data.argsort().argsort() 
ax[0,0].grid(False)
ax[0,1].grid(False)
ax[1,0].grid(False)
ax[1,1].grid(False)
ax[2,0].grid(False)


# Caronas
ax2 = sns.barplot(x= df_copia["8. Ao oferecer uma carona o quão importante é: [Saber previamente o trajeto?]"].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia["8. Ao oferecer uma carona o quão importante é: [Saber previamente o trajeto?]"].value_counts().index, 
                  palette=np.array(pal[::-1])[rank], ax = ax[0,0])
ax2.set_title("Saber previamente o trajeto?");

# Transporte Público
ax2 = sns.barplot(x= df_copia["8. Ao oferecer uma carona o quão importante é: [Saber previamente dados do usuário?]"].value_counts().values/df_copia.shape[0] * 100,
                  y= df_copia["8. Ao oferecer uma carona o quão importante é: [Saber previamente dados do usuário?]"].value_counts().sort_values(ascending = False).index , 
                  ax = ax[0,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Saber previamente dados do usuário?");

# Taxi/Uber
ax2 = sns.barplot(x= df_copia['8. Ao oferecer uma carona o quão importante é: [Dividir as despesas?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao oferecer uma carona o quão importante é: [Dividir as despesas?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("Dividir as despesas?");
    
# Motorista do gênero oposto
ax2 = sns.barplot(x= df_copia['8. Ao oferecer uma carona o quão importante é: [Conversar previamente com o usuário?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao oferecer uma carona o quão importante é: [Conversar previamente com o usuário?]'].value_counts().sort_values(ascending = False).index , ax = ax[1,1], palette=np.array(pal[::-1])[rank])
ax2.set_title("Conversar previamente com o usuário?");

# Motorista do mesmo gênero
ax2 = sns.barplot(x= df_copia['8. Ao oferecer uma carona o quão importante é: [Ter o gênero do usuário verificado?]'].value_counts().values/df_copia.shape[0] * 100, 
                  y= df_copia['8. Ao oferecer uma carona o quão importante é: [Ter o gênero do usuário verificado?]'].value_counts().sort_values(ascending = False).index , ax = ax[2,0], palette=np.array(pal[::-1])[rank])
ax2.set_title("Ter o gênero do usuário verificado?");

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Com base na análise explicitada previamente, constatamos o valor absoluto de mulheres que possuem veículo próprio, e portanto são candidatas para ofertar carona, bem como o oposto. Além disso, obtivemos a porcentagem de cada dado e distrinchamos perguntas realizadas durante a coleta de dados para entender mais adequadamente o nosso <b>perfil de usuário</b>.
# Ademais, com os dados obtidos, foi possível verificar o quão segura as mulheres se sentem em diversas situações ao requisitar uma carona, e o quão importante alguns tópicos são para mulheres que iriam ofertá-la, o que responde a diversos questionamentos durante o planejamento da coleta e nos aproxima da construção de um sistema útil ao usuário final.
